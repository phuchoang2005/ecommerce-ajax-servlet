# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 6.1 MB/s  0:00:01m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 10.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root123",
)
conn.cursor().execute("use ecommerce_new")

# %%
import pandas as pd
def execute_query(title, sql):
    print(f"🔍 {title}")
    try:
            # Sử dụng pandas để đọc và hiển thị cho đẹp
        df = pd.read_sql(sql, conn)
        if df.empty:
            print("Không tìm thấy kết quả phù hợp.")
        else:
            display(df) # Hàm display chuyên dùng cho Jupyter
        print("-" * 50)
    except Exception as e:
        print(f"❌ Lỗi: {e}")

# %%
execute_query("Select all users", "select * from users;")
# Out:
# 🔍 Select all users
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_41669/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#     user_id    username                                           password  \
# 0         1  admin_user                                        P@ssw0rd123
# 1         2  customer01                                        password123
# 2         3     airflow  $2a$10$PKIBC.hpwjPfsZBC4T5VkeEyii56A.smwttMj/B...
# 3         4   airflow_2  $2a$10$ZOeeXfpofyHPDwAICUW3Y.93DoPXSpPGxBfAwBH...
# 4         5   airflow_3  $2a$10$d52CEJCAjv.33peww6iGtOUmiBHIQa.0q1vo8/u...
# 5         6   airflow_4  $2a$10$.qF4vG0C3duncXrp8.vXxeDBd.lSBi85gSgqR3C...
# 6         7   airflow_5  $2a$10$Uk9XR7z.wNNiPMTSOzgY.uAZFXsjOAsz3eIximz...
# ...

# %%
execute_query("SELECT ALL PROFILES", "select * from profiles;")
# Out:
# 🔍 SELECT ALL PROFILES
# Không tìm thấy kết quả phù hợp.
# --------------------------------------------------
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_41669/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)

# %%
# !python dropdb.py
# Out:
# ^C
