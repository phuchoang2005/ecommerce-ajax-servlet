# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 936.8 kB/s eta 0:00:00m eta -:--:--
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 742.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 628.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.2 pandas-3.0.1

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root123",
)
conn.cursor().execute("use ecommerce_new")

# %%
import pandas as pd
def execute_query(title, sql):
    print(f"🔍 {title}")
    try:
            # Sử dụng pandas để đọc và hiển thị cho đẹp
        df = pd.read_sql(sql, conn)
        if df.empty:
            print("Không tìm thấy kết quả phù hợp.")
        else:
            display(df) # Hàm display chuyên dùng cho Jupyter
        print("-" * 50)
    except Exception as e:
        print(f"❌ Lỗi: {e}")

# %%
execute_query("Select all users", "select * from users;")
# Out:
# 🔍 Select all users
# /tmp/ipykernel_14843/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    user_id    username                                           password  \
# 0        1  admin_user                                        P@ssw0rd123
# 1        2  customer01                                        password123
# 2        3     airflow  $2a$10$0s9CP7lvX41cDHpVsmq8NeXJsijkgxgKzvMBs.r...
# 3        5   airflow_1  $2a$10$s/H1c50uyAYtFnutGpXaie7KhO9Vofq6BWlRi84...
#
#     role          created_at          updated_at
# 0  ADMIN 2026-03-09 03:38:42 2026-03-09 03:38:42
# 1   USER 2026-03-09 03:38:42 2026-03-09 03:38:42
# 2   USER 2026-03-09 03:39:32 2026-03-09 03:39:32
# 3   USER 2026-03-09 03:40:02 2026-03-09 03:40:02
# --------------------------------------------------

# %%
execute_query("SELECT ALL PROFILES", "select * from profiles;")
# Out:
# 🔍 SELECT ALL PROFILES
# /tmp/ipykernel_14843/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    profile_id  user_id  full_name      phone                email address
# 0           1        3  hoangphuc  012345678  airflow@example.com    hcmc
# --------------------------------------------------
