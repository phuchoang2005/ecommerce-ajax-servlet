# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/phuchoang/Documents/ecommerce-ajax-servlet/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root123",
)
conn.cursor().execute("use ecommerce_new")

# %%
import pandas as pd
def execute_query(title, sql):
    print(f"🔍 {title}")
    try:
            # Sử dụng pandas để đọc và hiển thị cho đẹp
        df = pd.read_sql(sql, conn)
        if df.empty:
            print("Không tìm thấy kết quả phù hợp.")
        else:
            display(df) # Hàm display chuyên dùng cho Jupyter
        print("-" * 50)
    except Exception as e:
        print(f"❌ Lỗi: {e}")

# %%
execute_query("Select all users", "select * from users;")
# Out:
# 🔍 Select all users
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_3072/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#     user_id    username                                           password  \
# 0         1  admin_user                                        P@ssw0rd123
# 1         2  customer01                                        password123
# 2         3     airflow  $2a$10$0dppWho1zE/O.p7QKYjT7u1g.0NYRSAqtxjJsJd...
# 3         5   airflow_2  $2a$10$lxyfXr65ezingGEKGtkbG.UyEsmIVICDxlH07s5...
# 4         6   airflow_3  $2a$10$3McGuz2aTfSajuyNkZZ3uea06Q5cUSjn/20zuNm...
# 5         7   airflow_4  $2a$10$iZpsBo.8rI01HOQFCTxD1u/ZymKJtA6mrtBWRoL...
# 6         8   airflow_5  $2a$10$Q2JE0AjvSBeOXVaPTjiTZ.ozFxDODDZPQQKrL1b...
# 7         9   airflow_6  $2a$10$pll/2ZAVCKuB/tMu2pZQF.CHa6zofVvT6FqbMHa...
# 8        10   airflow_7  $2a$10$PNn.5BPnYunyJPvV9/x.M.QDaRBbCvpAVJpsYKB...
# 9        11   airflow_8  $2a$10$cmZ/ALM4A/8zo8p5MD7rVeVHUW5vxDkBCh5Fvky...
# 10       15   airflow_9  $2a$10$q8prN2qyh0Se0JjMHhjnKekmRCklGPbt4GWLFSR...
#
#      role          created_at          updated_at
# 0   ADMIN 2026-03-12 10:35:30 2026-03-12 10:35:30
# 1    USER 2026-03-12 10:35:30 2026-03-12 10:35:30
# 2    USER 2026-03-12 10:36:12 2026-03-12 10:36:12
# 3    USER 2026-03-12 10:52:53 2026-03-12 10:52:53
# 4    USER 2026-03-12 10:57:07 2026-03-12 10:57:07
# 5    USER 2026-03-12 10:59:03 2026-03-12 10:59:03
# 6    USER 2026-03-12 11:00:43 2026-03-12 11:00:43
# 7    USER 2026-03-12 11:09:38 2026-03-12 11:09:38
# 8    USER 2026-03-12 11:23:30 2026-03-12 11:23:30
# 9    USER 2026-03-12 11:26:36 2026-03-12 11:26:36
# 10   USER 2026-03-12 11:29:28 2026-03-12 11:29:28
# --------------------------------------------------

# %%
execute_query("SELECT ALL PROFILES", "select * from profiles;")
# Out:
# 🔍 SELECT ALL PROFILES
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_3072/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#    profile_id  user_id     full_name       phone                   email  \
# 0           1        3  nguyen van a   012345678  nguyenvana@example.com
# 1          13       15  nguyen van b  0123456789  nguyenvanb@example.com
#
#   address
# 0    hcmc
# 1    hcmc
# --------------------------------------------------
