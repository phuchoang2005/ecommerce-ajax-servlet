# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 9.7 MB/s  0:00:016m0:00:010:01
# Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 13.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.4 pandas-3.0.2
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root123",
)
conn.cursor().execute("use ecommerce")

# %%
import pandas as pd
def execute_query(title, sql):
    print(f"🔍 {title}")
    try:
            # Sử dụng pandas để đọc và hiển thị cho đẹp
        df = pd.read_sql(sql, conn)
        if df.empty:
            print("Không tìm thấy kết quả phù hợp.")
        else:
            display(df) # Hàm display chuyên dùng cho Jupyter
        print("-" * 50)
    except Exception as e:
        print(f"❌ Lỗi: {e}")

# %%
execute_query("Select all users", "select * from users;")
# Out:
# 🔍 Select all users
# ❌ Lỗi: 1146 (42S02): Table 'ecommerce.users' doesn't exist
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_49639/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)

# %%
execute_query("SELECT ALL PROFILES", "select * from profiles;")
# Out:
# 🔍 SELECT ALL PROFILES
# ❌ Lỗi: 1146 (42S02): Table 'ecommerce.profiles' doesn't exist
# /var/folders/5z/yslry4896h775tdtwm9wbfq40000gn/T/ipykernel_49639/314929007.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
